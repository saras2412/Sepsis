# %%
import os #import os before getting the working directory
os.getcwd()
# Out:
# 'C:\\Users\\GingeR\\AppData\\Local\\Programs\\Python\\Python37-32'

# %%
import pandas as pd #import pandas

# %%
p000001 = pd.read_csv(r"C:\Users\GingeR\AppData\Local\Programs\Python\Python37-32\p000001.psv",sep = "|") #loading a single .psv file
p000001
# Out:
#        HR  O2Sat   Temp    SBP     MAP  DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 0     NaN    NaN    NaN    NaN     NaN  NaN   NaN    NaN         NaN   NaN
# 1    97.0   95.0    NaN   98.0   75.33  NaN  19.0    NaN         NaN   NaN
# 2    89.0   99.0    NaN  122.0   86.00  NaN  22.0    NaN         NaN   NaN
# 3    90.0   95.0    NaN    NaN     NaN  NaN  30.0    NaN        24.0   NaN
# 4   103.0   88.5    NaN  122.0   91.33  NaN  24.5    NaN         NaN   NaN
# 5   110.0   91.0    NaN    NaN     NaN  NaN  22.0    NaN         NaN   NaN
# 6   108.0   92.0  36.11  123.0   77.00  NaN  29.0    NaN         NaN   NaN
# 7   106.0   90.5    NaN   93.0   76.33  NaN  29.0    NaN         NaN   NaN
# 8   104.0   95.0    NaN  133.0   88.33  NaN  26.0    NaN         NaN   NaN
# 9   102.0   91.0    NaN  134.0   87.33  NaN  30.0    NaN         NaN   NaN
# 10  104.0   92.0  37.17  138.0   86.67  NaN  19.0    NaN        23.0   NaN
# ...

# %%
pip install sparkmagic
# Out:
# ...
#   Running setup.py install for hdijupyterutils: started
#     Running setup.py install for hdijupyterutils: finished with status 'done'
#   Running setup.py install for retrying: started
#     Running setup.py install for retrying: finished with status 'done'
#   Running setup.py install for autovizwidget: started
#     Running setup.py install for autovizwidget: finished with status 'done'
#   Running setup.py install for pycparser: started
#     Running setup.py install for pycparser: finished with status 'done'
#   Running setup.py install for sparkmagic: started
#     Running setup.py install for sparkmagic: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sparkmagic as spark

# %%
val_df1 = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("C:/Users/GingeR/AppData/Local/Programs/Python/Python37-32/training_setA.zip/training/*.psv").select([column])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-60e30f03410e> in <module>
# ----> 1 val_df1 = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("C:/Users/GingeR/AppData/Local/Programs/Python/Python37-32/training_setA.zip/training/*.psv").select([column])
#
# AttributeError: module 'sparkmagic' has no attribute 'read'

# %%
from glob import glob # import glob

TrainingA = glob(r"C:\Users\GingeR\AppData\Local\Programs\Python\Python37-32\training_setA.zip\training\*.psv") #combines all the .psv files from the dir and stores in the variable
df_list = [] #defining list
for filename in sorted(TrainingA):
    df_list.append(pd.read_csv(filename))
    full_df= pd.concat(df_list)
    
    full_df.to_csv(r"C:\Users\GingeR\AppData\Local\Programs\Python\Python37-32\Dataset_A.csv")  #Saving the merged files (SetA) in the same directory

# %%
 pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import openpyxl

# %%
dataset = pd.read_csv(r"C:\Users\GingeR\AppData\Local\Programs\Python\Python37-32\Dataset_A.csv" , sep = "|")
dataset
#dataset.to_excel('Set_A.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-dfbe3b3bd4e9> in <module>
# ----> 1 dataset = pd.read_csv(r"C:\Users\GingeR\AppData\Local\Programs\Python\Python37-32\Dataset_A.csv" , sep = "|")
#       2 dataset
#       3 #dataset.to_excel('Set_A.xlsx')
#       4
#
# ...
